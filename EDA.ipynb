# %%
import pandas as pd
import numpy as np

# %%
pro='E:\제5회 Big Data Competition-Digital Trend Analyzer\제5회 Big Data Competition-분석용데이터-01.Pruduct.csv'
sea1='E:\제5회 Big Data Competition-Digital Trend Analyzer\제5회 Big Data Competition-분석용데이터-02.Search1.csv'
sea2='E:\제5회 Big Data Competition-Digital Trend Analyzer\제5회 Big Data Competition-분석용데이터-03.Search2.csv'
cus='E:\제5회 Big Data Competition-Digital Trend Analyzer\제5회 Big Data Competition-분석용데이터-04.Custom.csv'
sess='E:\제5회 Big Data Competition-Digital Trend Analyzer\제5회 Big Data Competition-분석용데이터-05.Session.csv'
mas='E:\제5회 Big Data Competition-Digital Trend Analyzer\제5회 Big Data Competition-분석용데이터-06.Master.csv'

# %%
product = pd.read_csv(pro, engine='python',sep='\t')

# %%
search1 = pd.read_csv(sea1, engine='python',sep=',')

# %%
search2 = pd.read_csv(sea2, engine='python',sep=',')

# %%
custom = pd.read_csv(cus, engine='python',sep=',')

# %%
session = pd.read_csv(sess, engine='python',sep=',')

# %%
master = pd.read_csv(mas, engine='python',sep=',')

# %%
product.head(10)
# Out:
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                         PD_ADD_NM  \
# 0       25   7605037        12  642112                           색상:워터멜론
# 1       25  10189797        13  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개
# 2       33   6158159        85  179538                                na
# 3       56   7935714        12  554336      색상:블랙|사이즈:160cm(12~13세) / 1개
# 4       56   6406509        78  190306                                5개
# 5       59   4050743        66  149995            사이즈:옵션04.AN868_04 / 1개
# 6       68   6881895        10  568751             신발색상:블랙(BK)/신발사이즈:280
# 7       71   6537318        21  570603  색상:BLK0_(BLK0)BLACK|사이즈:115 / 1개
# 8      121   3942102         2  755148                     모델명:올나이터 / 1개
# 9      135   5718021        19  608620                        사이즈:7 / 1개
#
#   PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0   [바비브라운]    39,000         1
# 1       데상트    39,000         2
# 2     [아베다]    39,000         1
# 3   아디다스 키즈    39,000         1
# ...

# %%
search1.head(10)
# Out:
#    CLNT_ID  SESS_ID      KWD_NM  SEARCH_CNT
# 0  5607714  7112876    빌리프 아이크림           6
# 1  5607714  4090791   프리메라 마스크팩           3
# 2  5607714  4090791       여성청결제           1
# 3  5612428  1876482        명품가방           1
# 4  5612428   658123   콩순이 아이스크림           1
# 5  5612428  1876482  블루독 티셔츠 남아           1
# 6  5612471  8539312       쉬폰원피스           1
# 7  5612471  8539312  여성 쉬폰 블라우스           1
# 8  5613055  8510027      임산부 팬티           2
# 9  5613055  8510027     임산부 원피스           1

# %%
search2.head(10)
# Out:
#     SESS_DT     KWD_NM SEARCH_CNT
# 0  20180407      닥스원피스          8
# 1  20180407  닥터지 브라이트닝          1
# 2  20180407     달팡 인트랄          2
# 3  20180407        대상트          1
# 4  20180407       더블유닷          6
# 5  20180407  더블하트 모유실감          1
# 6  20180407   데님 롱 스커트          6
# 7  20180407     데상트 크론         12
# 8  20180407    데상트골프여성          6
# 9  20180407    데상트여성골프          1

# %%
custom.head(10)
# Out:
#    CLNT_ID CLNT_GENDER  CLNT_AGE
# 0  4830726           F        30
# 1  4830874           F        40
# 2  4830975           F        30
# 3  4831275           F        30
# 4  4825325           F        30
# 5  4825382           F        40
# 6  4825797           F        40
# 7  4825908           F        30
# 8  4825961           F        30
# 9  4840532           M        40

# %%
session.head(10)
# Out:
#    癤�"CLNT_ID"   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 0      5873599   8641867         9  20180509             82.0         1,890
# 1      5873599   6616320        21  20180611            105.0         1,604
# 2      5873599   5886172        40  20180624             41.0           632
# 3      5873884   1050889        15  20180913            160.0         1,035
# 4      5874461  10298270         5  20180412             13.0           298
# 5      5874701    608577        65  20180920             41.0           444
# 6      5874829   1666766        87  20180903             36.0           340
# 7      5874829   1670494        86  20180903            103.0           976
# 8      5874829   1694242        85  20180902            154.0         3,099
# 9      5874829   1559438        92  20180904             24.0           317
#
#   DVC_CTG_NM       ZON_NM  CITY_NM
# 0     mobile      Daejeon  Daejeon
# 1     mobile        Busan    Busan
# ...

# %%
master.head(100)
# Out:
#       PD_C                                              PD_NM   CLAC1_NM  \
# 0    64382   언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]      스포츠패션
# 1    62282                         여자 플라워덧신 2족선물세트 17403-2set  속옷/양말/홈웨어
# 2    61729                       88A2933253배트맨스웨트티 - 블랙 / 130      유아동의류
# 3    61537            닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)       패션잡화
# 4    58820  여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) - 회색(앤틱실버...       남성의류
# 5    58280                 선염스트라이프레이스패치원피스 JROP521D - 블루 / 85       여성의류
# 6    58183     [17S/S]  울 자카드 져지 자켓 9317111001056 - 네이비 / 100       남성의류
# 7    58098         V넥 고방 체크 롱 원피스 (K65-54615) - 스카이블루(SB) / F       여성의류
# 8    58057               배색포인트 랩스타일 원피스 (GIHOP921F) - 화이트 / F       여성의류
# 9    56306                  선염 체크나염 여성잠옷(VPT3570WP) - 핑크 / 95  속옷/양말/홈웨어
# 10   55076                  정장형스판바지C72P158 - 베이지(BE) / 55(90)       여성의류
# 11  318122                         H1280YRJ,K,N토트백&크로스백 - 그레이       패션잡화
# ...
